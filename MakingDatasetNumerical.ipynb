# %%
import pandas as pd

df = pd.read_csv("diabetes_engineered_normalized_balanced.csv")
df.head()
# Out:
#         age  hypertension  heart_disease smoking_history       bmi  \
# 0  1.389214             0              1          former  0.326336
# 1  0.810480             0              0         No Info -1.390648
# 2  1.611804             0              0           never  1.846798
# 3  0.676926             0              0           never  0.098784
# 4  1.077588             0              0           never -0.012037
#
#    HbA1c_level  blood_glucose_level  diabetes age_group  gender_Female  ...  \
# 0     0.155970             1.510204         1       Old          False  ...
# 1     2.485395            -0.298664         1     Adult           True  ...
# 2     1.180917             0.410216         1       Old           True  ...
# 3     0.528678             0.043554         1     Adult          False  ...
# 4     1.833156             0.532437         1       Old           True  ...
#
#    Female_Child  Female_Adult  Female_Old  Other_Child  Other_Adult  \
# ...

# %%
print(df.columns)
# Out:
# Index(['age', 'hypertension', 'heart_disease', 'smoking_history', 'bmi',
#        'HbA1c_level', 'blood_glucose_level', 'diabetes', 'age_group',
#        'gender_Female', 'gender_Male', 'gender_Other', 'Male_Child',
#        'Male_Adult', 'Male_Old', 'Female_Child', 'Female_Adult', 'Female_Old',
#        'Other_Child', 'Other_Adult', 'Other_Old', 'age_squared',
#        'bmi_category', 'HbA1c_above_6_5', 'blood_glucose_above_126'],
#       dtype='object')

# %%
unique_values_smoking_history = df['smoking_history'].unique()
print(unique_values_smoking_history)
# Out:
# ['former' 'No Info' 'never' 'current' 'not current']

# %%
unique_values_smoking_history = df['age_group'].unique()
print(unique_values_smoking_history)
# Out:
# ['Old' 'Adult' 'Child']

# %%
unique_values_smoking_history = df['bmi_category'].unique()
print(unique_values_smoking_history)
# Out:
# ['Overweight' 'Underweight' 'Obese' 'Normal weight']

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is already defined

# Initialize label encoder
label_encoder = LabelEncoder()

# Convert 'smoking_history' into numerical values
df['smoking_history'] = label_encoder.fit_transform(df['smoking_history'])

# Convert 'age_group' into numerical values
df['age_group'] = label_encoder.fit_transform(df['age_group'])

# Convert 'gender' columns (binary: Female, Male, Other) into numerical values
df['gender_Female'] = df['gender_Female'].astype(int)
df['gender_Male'] = df['gender_Male'].astype(int)
df['gender_Other'] = df['gender_Other'].astype(int)

# Convert 'bmi_category' into numerical values
df['bmi_category'] = label_encoder.fit_transform(df['bmi_category'])

# Display the first few rows of the transformed dataframe to verify
print(df.head())
# Out:
#         age  hypertension  heart_disease  smoking_history       bmi  \
# 0  1.389214             0              1                2  0.326336
# 1  0.810480             0              0                0 -1.390648
# 2  1.611804             0              0                3  1.846798
# 3  0.676926             0              0                3  0.098784
# 4  1.077588             0              0                3 -0.012037
#
#    HbA1c_level  blood_glucose_level  diabetes  age_group  gender_Female  ...  \
# 0     0.155970             1.510204         1          2              0  ...
# 1     2.485395            -0.298664         1          0              1  ...
# 2     1.180917             0.410216         1          2              1  ...
# 3     0.528678             0.043554         1          0              0  ...
# 4     1.833156             0.532437         1          2              1  ...
#
#    Female_Child  Female_Adult  Female_Old  Other_Child  Other_Adult  \
# ...

# %%
df.to_csv('diabetes_engineered_normalized_balanced_allNumerical.csv', index=False)
